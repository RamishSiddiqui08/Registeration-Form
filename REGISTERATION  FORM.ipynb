# %%
from tkinter import*
import tkinter as tk
import turtle as tu

# %%
root=tk.Tk()
root.title("Registration Form")
root.configure(bg="light grey")
root.geometry("700x700")
#Labels
a= Label(root,text="Registration Form",font="50",bg="white")
a.pack(fill=X)
name=tk.StringVar()
b= Label(root,text="Full Name",font="20")
b.place(x=80,y=50)
c= Label(root,text="Email",font="20")
c.place(x=80,y=125)
v=IntVar()
d= Label(root,text="Gender",font="20")
d.place(x=80,y=200)
r1= Radiobutton(root,text="Male",font="arial,20",variable=v,value =10)
r1.place(x=150,y=200)
e= Label(root,text="Gender",font="20")
e.place(x=80,y=200)
r2= Radiobutton(root,text="Female",font="arial,20",variable=v,value=20)
r2.place(x=250,y=200)
f= Label(root,text="Gender",font="20")
f.place(x=80,y=200)
y= Label(root,text="Country",font="20")
y.place(x=20,y=275)
ram= Label(root,text="Programming Language",font="20")
ram.place(x=80,y=500)
r3= Radiobutton(root,text="Java",font="arial,20",variable=v,value =10)
r3.place(x=300,y=500)
r4= Radiobutton(root,text="Python",font="arial,20",variable=v,value=20)
r4.place(x=400,y=500)

#entry
fullnameValue=StringVar()
emailValue=StringVar()
fullname= Entry(root,textvariable=fullnameValue,width=30,bd=2,font="20")
fullname.place(x=180,y=50)
email= Entry(root,textvariable=emailValue,width=30,bd=2,font="20")
email.place(x=180,y=125)
#list
list1= Listbox (root,font="arial,20")
list1.insert(0,"Select your Country")
list1.insert(1,"Pakistan")
list1.insert(2,"India")
list1.insert(3,"USA")
list1.insert(4,"China")
list1.insert(5,"Bangladesh")
list1.insert(6,"UK")
list1.insert(7,"Canada")
def select():
    hello.config(text=list1.get(ANCHOR))
Butoon= Button(root,text="Select",command=select)
Butoon.place(x=80,y=430)
hello= Label(root,text='')
hello.pack(fill=X)
list1.place(x=80,y=275)
#submit button and pop up window
def clicker():
    global pop
pop= Toplevel(root)
pop.title("Task achieved")
pop.geometry("50x100")
pop .config(bg="black")
pop_label= Label(pop, text="Successful Login",bg="green",font="helvetica,12")
pop_label.pack(pady=10)
        
framey= Frame(pop,bg="red")
framey.pack(pady=5)
        
popbutton= Button(root,text="Submit",bg="red",fg="white",command=clicker,font="25")       
popbutton.place(x=100,y=550 )
    

root.mainloop()
